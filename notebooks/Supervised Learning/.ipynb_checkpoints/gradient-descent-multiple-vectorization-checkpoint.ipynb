# %% [markdown]
# # Gradient descent for multiple regresion

# %% [markdown]
# First of all, we are going to import the necessary libraries:
#
# - Pandas: to handle and manipulate the dataset.
# - NumPy: to perform numerical operations and array manipulations.
# - Matplotlib: to visualize the data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# We will load the insurance dataset ([link](https://www.kaggle.com/datasets/mirichoi0218/insurance)) from a CSV file and visualize head.

# %%
df = pd.read_csv("../../datasets/insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# As we can see, the dataset contains six features: age, sex, bmi, children, smoker, and region, but only two of them, age and bmi, are numerical.<br>
# We can visualize it individual

# %%
features = ["age", "bmi"]
for feature in features:
    plt.figure()
    plt.scatter(df[feature], df["charges"], s=.5)
    plt.xlabel(feature)
    plt.ylabel("charges")
    plt.title(f"charges vs {feature}")
    plt.show()

# %% [markdown]
# We define the feature matrix using these variables and set charges as the target variable.

# %%
X_train = df.drop(columns=["sex","children", "smoker", "region", "charges"]).to_numpy()
y_train = df["charges"].to_numpy()

# %% [markdown]
# Now we are going to  define the cost function

# %%
#Function to calculate the cost
def compute_cost(X, y, w, b):
    """
    compute cost
    Args:
      X (ndarray (m,n)): Data, m examples with n features
      y (ndarray (m,)) : target values
      w (ndarray (n,)) : model parameters  
      b (scalar)       : model parameter
      
    Returns:
      cost (scalar): cost
    """
    
    m = X.shape[0]
    cost = 0.0
    for i in range(m):
        f_wb_i = np.dot(X[i], w) + b
        cost += (f_wb_i - y[i])**2
    cost /= 2 * m
    return cost

# %% [markdown]
# Same for the gradient function

# %%
def compute_gradient(X, y, w, b):

    """
    Computes the gradient for linear regression 
    Args:
      x (ndarray): Data, m examples 
      y (ndarray): target values
      w, b (scalar) : model parameters  
    Returns
      dj_dw (scalar): The gradient of the cost w.r.t. the parameters w
      dj_db (scalar): The gradient of the cost w.r.t. the parameter b     
     """
    
    m, n = X.shape
    dj_dw = np.zeros((n,))
    dj_db = 0.
    
    for i in range(m):
        err = (np.dot(X[i], w) + b) - y[i]
        for j in range(n):
            dj_dw[j] += err * X[i, j]
        dj_db += err
    dj_dw /= m
    dj_db /= m
    
    return dj_dw, dj_db

# %% [markdown]
# Lastly we define the gradient descent

# %%
import copy
import math

def gradient_descent(X, y, w_in, b_in, alpha, cost_function, gradient_function, num_iters):
    """
    Performs batch gradient descent to learn theta. Updates theta by taking 
    num_iters gradient steps with learning rate alpha
    
    Args:
      X (ndarray (m,n))   : Data, m examples with n features
      y (ndarray (m,))    : target values
      w_in (ndarray (n,)) : initial model parameters  
      b_in (scalar)       : initial model parameter
      cost_function       : function to compute cost
      alpha (float)       : Learning rate
      gradient_function   : function to compute the gradient
      num_iters (int)     : number of iterations to run gradient descent
      
    Returns:
      w (ndarray (n,)) : Updated values of parameters 
      b (scalar)       : Updated value of parameter 
      """
    J_history = []
    w = copy.deepcopy(w_in)  #avoid modifying global w within function
    b = b_in
    
    for i in range(num_iters):

        # Calculate the gradient and update the parameters
        dj_dw,dj_db = gradient_function(X, y, w, b)   ##None

        # Update Parameters using w, b, alpha and gradient
        w = w - alpha * dj_dw
        b = b - alpha * dj_db
      
        # Save cost J at each iteration
        if i<100000:      # prevent resource exhaustion 
            J_history.append( cost_function(X, y, w, b))

        # Print cost every at intervals 10 times or as many iterations if < 10
        if i% math.ceil(num_iters / 10) == 0:
            print(f"Iteration {i:4d}: Cost {J_history[-1]:8.2f}   ")
        
    return w, b, J_history #return final w,b and J history for graphing

# %%
# initialize parameters
initial_w = np.zeros((2,))
initial_b = 0.
# some gradient descent settings
iterations = 10000
alpha = 5.0e-7
# run gradient descent 
w_final, b_final, J_hist = gradient_descent(X_train, y_train, initial_w, initial_b,
                                                    alpha, compute_cost, 
                                                    compute_gradient, iterations)
print(f"b,w found by gradient descent: {b_final:0.2f},{w_final} ")
# Out:
# Iteration    0: Cost 161071565.87
# Iteration 1000: Cost 72266329.59
# Iteration 2000: Cost 65851358.01
# Iteration 3000: Cost 65387365.62
# Iteration 4000: Cost 65353255.53
# Iteration 5000: Cost 65350243.08
# Iteration 6000: Cost 65349520.69
# Iteration 7000: Cost 65349003.97
# Iteration 8000: Cost 65348539.05
# Iteration 9000: Cost 65348111.73
# b,w found by gradient descent: 4.19,[214.64093569 164.39892789]

# %% [markdown]
# Finally we can test with a sample of the data

# %%
for i in range(10):
    print(f"prediction: {np.dot(X_train[i], w_final) + b_final:0.2f}, target value: {y_train[i]}")
# Out:
# prediction: 8669.10, target value: 16884.924
# prediction: 9419.48, target value: 1725.5523
# prediction: 11439.30, target value: 4449.462
# prediction: 10820.02, target value: 21984.47061
# prediction: 11620.54, target value: 3866.8552
# prediction: 10889.69, target value: 3756.6216
# prediction: 15375.17, target value: 8240.5896
# prediction: 12506.33, target value: 7281.5056
# prediction: 12849.92, target value: 6406.4107
# prediction: 17130.71, target value: 28923.13692

# %%
test = np.array([23, 29.1])
print(f"prediction: {np.dot(test, w_final) + b_final:0.2f}")
# Out:
# prediction: 9724.94
